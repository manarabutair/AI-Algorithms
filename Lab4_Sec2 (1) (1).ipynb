# %% [markdown]
# <center><img src="https://drive.google.com/uc?export=view&id=1ia67jZrMZx4V45HYDM7pxcoZrPJE-NMP" alt="PSUT"  width="180px">
# <p>
# King Hussein School for Computing Sciences <br>
# Department of Data Science <br>
# Artificial Intelligence Lab <br>
# </p></center>
#
#
# <!-- **Title**:  *Review of Python*  -->
# <hr>
# <h4><b>Grading Criteria</b></h4>
#
# <table border>
# <tr>
# <td> <b>Exercise</b></td>
# <td> <b>Ex.1</b></td>
# <td> <b>Ex.2</b></td>
# </tr>
#
# <tr>
# <td> <b>Marks</b></td>
# <td> /4</td>
# <td> /6</td>
#
# </tr>
# <tr>
# <td> <b>Total</b></td>
# <th colspan=6> /10</th>
# </tr>
# </table>
#
# <h4><b>Lab Objectives</b></h4>
# <ul>
# <li> Familiarizing students with expert systems.
# <li> Practicing the logic programming in python.
# </ul>
#
# <h4><b>Lab Instructions</b></h4>
# <ul>
# <li> Create a new folder on desktop and name it by your “ID-FirstName-LastName-LabX”.
# <li> Create a new folder on Google drive and name it by your.“ID-FirstName-LastName-DE-Lab” and inside this folder create a new folder for each lab.
# <li> You must upload your solutions to e-learning as follows as .ipynb and .pdf (ctrl+P) files.
# <li> Each lab assignment is of 10 marks.</li>
# <li> <b>Do not</b> leave before discussing your solutions with the instructor. </li>
# </ul>

# %% [markdown]
# #Exercise 1:
# <h5> <u> Exercise Objectives: </u></h5>
#
# * Practicing logic programming.
#
# <u> Problem Description: </u>
#
# This graph includes 8 cities (i.e., A, B, C, D, E, F, G, H). The directed edge between two cities refers to a possible path. For example, you can go from city A to city B. In the next question, you will be asked to develop a simple expert system to answer "Is there a path from city X to city Y?".
#
# In this question, you are asked to write simple facts (as comments) to represent the following graph. For example, "There is a path from A to B". **SHOW THE FACTS TO THE INSTRUCTOR BEFORE THE IMPLEMENTATION.**
#
# ![image.png](data:image/png;base64,...)

# %%
# !pip install pytholog
import pytholog as pl
#There is a path from A to G
#There is a path from A to E
#There is a path from G to F
#There is a path from G to E
#There is a path from F to G
#There is a path from E to D
#There is a path from C to F
#There is a path from C to H
#There is a path from C to B
#There is a path from D to C

# %% [markdown]
# #Exercise 2:
# <h5> <u> Exercise Objectives: </u></h5>
#
# * Practicing logic programming.
#
#
# <u> Problem Description: </u>
#
# Implement a knowledge base called `country` that includes the following
#
# * The simple facts that you defined in Exercise 1.
# * Search if there is a path from A to G.
# * Search for cities that are connected with city C.
#
#
# <u> Sample Output: </u>
# ![image.png](data:image/png;base64,...)

# %%
new_kb=pl.KnowledgeBase('country')
new_kb(["path(a, g)", "path(a, e)", "path(g, f)", "path(g, e)", "path(f, g)", "path(e, d)", "path(c, f)", "path(c, h)", "path(c, b)", "path(d, c)"])
new_kb.query(pl.Expr("path(a, g)"))
print(new_kb.query(pl.Expr("path(City, c)")))
# Out:
# [{'City': 'd'}]
